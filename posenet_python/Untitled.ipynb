# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
df=pd.read_csv(".csv")
tes=df.reset_index()
tes.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-afd27e03eff8> in <module>
# ----> 1 df=pd.read_csv("kk.csv")
#       2 tes=df.reset_index()
#       3 tes.head()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
# plt.plot(tes['index'][:300],tes['L pelvis'][:300])
# plt.plot(tes['index'][:300],tes['R pelvis'][:300])
plt.plot(tes['index'],tes['L knee'])
plt.plot(tes['index'],tes['R knee'])
plt.show()

# %%
plt.plot(tes['index'],tes['L knee'])
plt.show()

# %%
df=pd.read_csv("좌우무릎고간_디그리.csv")
tes=df.reset_index()
tes.head()
# Out:
#    index    L pelvis    R pelvis      L knee      R knee
# 0      0  140.415829  138.272154  127.582944  128.402662
# 1      1  144.310899  126.849619  122.648553  139.905243
# 2      2  127.768932  131.371569  138.952221  142.005080
# 3      3  105.828772  131.979620  151.624862  157.371114
# 4      4   93.748401  146.647315  161.825322  142.542556

# %%
a=150
b=0
li=[]
for i in tes['L knee']:
    if i>a:
        a=i
    elif i<110 and a>150:
        li.append(a)
        a=150
        b+=1
max(li),min(li)
# Out:
# (179.95366828702623, 176.57566296796415)

# %%
a=180
b=0
li=[]
for i in tes['L knee']:
    if i<a:
        a=i
    elif i>150 and a<110:
        li.append(a)
        a=110
        b+=1
print(b)
max(li),min(li)
# Out:
# 15
# (100.05649719249932, 81.89598794298549)

# %%
a=150
b=0
li=[]
for i in tes['R knee']:
    if i>a:
        a=i
    elif i<110 and a>150:
        li.append(a)
        a=150
        b+=1
max(li),min(li)
# Out:
# (179.97029722150845, 178.03871286959205)

# %%
180,176
